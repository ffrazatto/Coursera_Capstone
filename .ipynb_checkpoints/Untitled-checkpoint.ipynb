# %%
#!pip install geocoder

# %%
import pandas as pd
import numpy as np
import folium 
import requests
import json
import matplotlib.cm as cm
import matplotlib.colors as colors
from pandas.io.json import json_normalize
from geopy.geocoders import Nominatim
from sklearn.cluster import KMeans

# %% [markdown]
# Credenciais

# %%
CLIENT_ID = '4TA3CJZNAX3YAOMWZ2ASBNZGULEUZI5E5OABCFPWXRV1UATU' #Foursquare ID
CLIENT_SECRET = 'TJGOQELC1CGZQSVX0QIQNHW3XCOXQJPN1OBSJDIYGLN1KRZX' #Foursquare Secret
VERSION = '20180605' #Foursquare API version

CA_Token = '063caa6671dd4c935642b093e58fc6fd'

# %% [markdown]
# Endereços

# %%
metodo = 'address'
parametro = 'cidade'
valor = 'Campinas'


#url_cep = 'https://www.cepaberto.com/api/v3/{}?{}={}'.format(
#    metodo,
#    parametro,
#    valor,
#    )

url_cep = 'https://www.cepaberto.com/api/v3/address'

headers = {'Authorization': 'Token token=063caa6671dd4c935642b093e58fc6fd'}
params = {'estado': 'SP', 'cidade' : 'São Paulo'}
response = requests.get(url_cep, headers=headers, params=params)


#url_fs = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
#            CLIENT_ID, 
#            CLIENT_SECRET, 
#            VERSION, 
#            lat, 
#            lng, 
#            radius, 
#            LIMIT)

# %%
url = "https://www.cepaberto.com/api/v3/address?estado=SP&cidade=Cosmopolis"
headers = {'Authorization': 'Token token=063caa6671dd4c935642b093e58fc6fd'}
response = requests.get(url, headers=headers)
response.json()
# Out:
# {}

# %%
import requests

url = "https://www.cepaberto.com/api/v3/address"
headers = {'Authorization': 'Token token=063caa6671dd4c935642b093e58fc6fd'}
params = {'estado': 'SP', 'cidade': 'Campinas', 'bairro':'Cidade Universitaria'}
response = requests.get(url, headers=headers, params=params)

print(response.json())
# Out:
# {}

# %%
columns_t = list(response.json())

df = pd.DataFrame(columns = columns_t)

df
#x['cidade'] = response.json()['cidade']['nome']
#x['latitude'] = response.json()['latitude']

#x = pd.DataFrame(response.json(), columns= columns_t[0])
#for key in columns:
#df_cep = pd.DataFrame.from_dict(response.json())
#df_cep = df_cep.astype(str)
#x
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#Define a function to read a series of names and coordinates and
#lists the first 100 venues located inside a radius of 500m from the neighborhood center. 

def getNearbyVenues(names, latitudes, longitudes, radius=9000, LIMIT = 1000):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
address = '13083-330 campinas'
geolocator = Nominatim(user_agent="bg_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude


#First Toronto map with all neighborhoods

##Create map with folium library and the latitude and longitude variables
map_bg = folium.Map(location=[latitude, longitude], zoom_start=13)

# add markers to map
#for lat, lng, borough, neighborhood in zip(df_info['Latitude'], 
#                                           df_info['Longitude'],
#                                           df_info['Borough'],
#                                           df_info['Neighborhood']):
    
    #Maker display info
#    label = '{}, {}'.format(neighborhood, borough)
#    label = folium.Popup(label, parse_html=True)
    
    #Markers appearance
#    folium.CircleMarker(
#        [lat, lng],
#        radius = 5,
#        popup = label,
#        color = '#FF0000',
#        fill = True,
#        fill_color = 'white',
#        fill_opacity = 0.7,
#        parse_html = False).add_to(map_canada)  
    
map_bg
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-142-b827cf5f93bf> in <module>
#       2 geolocator = Nominatim(user_agent="bg_explorer")
#       3 location = geolocator.geocode(address)
# ----> 4 latitude = location.latitude
#       5 longitude = location.longitude
#       6
#
# AttributeError: 'NoneType' object has no attribute 'latitude'

# %%
name = 'Teste'
lat = latitude
lng = longitude
radius=100000
LIMIT = 1000

url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)

# %%
results = requests.get(url).json()

# %%
venues_list = []
venues_list.append([(v['venue']['name'],
                     v['venue']['location']['lat'],
                     v['venue']['location']['lng'],
                     v['venue']['categories'][0]['name']) for v in results])

nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
nearby_venues.columns = ['Venue',
                         'Latitude',
                         'Longitude',
                         'Category']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-101-2a4938488770> in <module>
#       3                      v['venue']['location']['lat'],
#       4                      v['venue']['location']['lng'],
# ----> 5                      v['venue']['categories'][0]['name']) for v in results])
#       6
#       7 nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
#
# <ipython-input-101-2a4938488770> in <listcomp>(.0)
#       3                      v['venue']['location']['lat'],
#       4                      v['venue']['location']['lng'],
# ----> 5                      v['venue']['categories'][0]['name']) for v in results])
#       6
#       7 nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
#
# TypeError: string indices must be integers

# %%
results['response']['totalResults']
# Out:
# 219

# %%
nearby_venues.head()
# Out:
#                                  Venue   Latitude  Longitude  \
# 0                      Sorvetes Sergel -22.910407 -47.059610
# 1                       Oba Hortifruti -22.893291 -47.052956
# 2                   Outback Steakhouse -22.891978 -47.027489
# 3  Parque Portugal - Lagoa do Taquaral -22.872789 -47.048550
# 4          Sociedade Hípica - Academia -22.897169 -47.020255
#
#                   Category
# 0           Ice Cream Shop
# 1  Fruit & Vegetable Store
# 2               Steakhouse
# 3                     Park
# 4                      Gym

# %%
address = 'Barão Geraldo, Campinas'
geolocator = Nominatim(user_agent="bg_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude


#First Toronto map with all neighborhoods

##Create map with folium library and the latitude and longitude variables
map_bg = folium.Map(location=[latitude, longitude], zoom_start=13)

# add markers to map
for lat, lng, cate in zip(nearby_venues['Latitude'], 
                                           nearby_venues['Longitude'],
                                           nearby_venues['Category']):
    
    #Maker display info
    label = '{}'.format(cate)
    label = folium.Popup(label, parse_html=True)
    
    #Markers appearance
    folium.CircleMarker(
        [lat, lng],
        radius = 5,
        popup = label,
        color = '#FF0000',
        fill = True,
        fill_color = 'white',
        fill_opacity = 0.7,
        parse_html = False).add_to(map_bg)  
    
map_bg
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
f1 = pd.read_html('https://cep.guiamais.com.br/busca/barao+geraldo-campinas-sp?page=1', encoding='utf-8')
f2 = pd.read_html('https://cep.guiamais.com.br/busca/barao+geraldo-campinas-sp?page=2', encoding='utf-8')
f3 = pd.read_html('https://cep.guiamais.com.br/busca/barao+geraldo-campinas-sp?page=3', encoding='utf-8')

# %%
df1 = f1[0]
df2 = f2[0]
df3 = f3[0]

# %%
x = df1.append(df2, ignore_index=True)
x = x.append(df3, ignore_index=True)

# %%
raw = []
for i in range(6): 
    raw.append(pd.read_html('https://cep.guiamais.com.br/busca/barao+geraldo-campinas-sp?page={}'.format(i+1), encoding='utf-8'))

# %%
df = pd.DataFrame(columns = ['LOGRADOURO', 'BAIRRO', 'CIDADE/ESTADO', 'BAIRRO.1', 'CEP'])

for d in raw:
    df = df.append(d[0], ignore_index = True)

df = df.astype(str)

# %%
df.drop(columns = ['LOGRADOURO', 'BAIRRO.1'], inplace=True)

# %%
df.sort_values(by=['BAIRRO'], inplace=True)
df['CEP'] = df['CEP'].str.replace(r'-', '')
df['CEP']
# Out:
# 70     13084070
# 92     13084175
# 90     13084030
# 87     13084020
# 83     13084015
#          ...
# 107    13082828
# 56     13082841
# 15     13082830
# 129    13082843
# 49     13082837
# Name: CEP, Length: 142, dtype: object

# %%
url1 = "https://www.cepaberto.com/api/v3/cep?cep={}".format(df['CEP'][1])
# O seu token está visível apenas pra você
headers = {'Authorization': 'Token token=063caa6671dd4c935642b093e58fc6fd'}
response = requests.get(url1, headers=headers)

# %%
df_barao = pd.DataFrame(columns = ['bairro', 'cep', 'latitude', 'longitude'])

# %%
import time

df_barao = pd.DataFrame(columns = ['bairro', 'cep', 'latitude', 'longitude'])

for d in df['CEP']:
    url = "https://www.cepaberto.com/api/v3/cep?cep={}".format(d)
    headers = {'Authorization': 'Token token=063caa6671dd4c935642b093e58fc6fd'}
    response = requests.get(url, headers=headers)

    if response.status_code != 200:
            print('REQUEST: FORBIDDEN!:',response.status_code)
            while response.status_code != 200:
                time.sleep(1)
                response = requests.get(url, headers=headers)
            print('SOLVED: 400 -> 200')
            #j = response.json()

            
    elif response.status_code == 200:
            print('REQUEST: OK')
            
    j = response.json()
    df_barao = df_barao.append({'bairro' : j['bairro'],
                                'cep' : j['cep'],
                                'latitude' : j['latitude'],
                                'longitude' : j['longitude']},
                               ignore_index=True)





#for d in df['CEP']:
#    url = "https://www.cepaberto.com/api/v3/cep?cep={}".format(d)
#    headers = {'Authorization': 'Token token=063caa6671dd4c935642b093e58fc6fd'}
#    response = requests.get(url, headers=headers)
#    j = response.json()
#    print(j)
#    df_barao = df_barao.append({'bairro' : j['bairro'],
#                                'cep' : j['cep'],
#                                'latitude' : j['latitude'],
#                                'longitude' : j['longitude']},
#                               ignore_index=True)

    #    df_barao = df_barao.append({'bairro' : response.json()['bairro'],
#                                'cep' : response.json()['cep'],
#                                'latitude' : response.json()['latitude'],
#                                'longitude' : response.json()['longitude']},
#                               ignore_index=True)
print('DONE!')
# Out:
# REQUEST: OK
# REQUEST: OK
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# REQUEST: OK
# REQUEST: OK
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# REQUEST: OK
# REQUEST: OK
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# REQUEST: OK
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# REQUEST: OK
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# ...

# %%
df_barao.head()
# Out:
#           bairro       cep     latitude    longitude
# 0  Barão Geraldo  13084070  -22.8283775  -47.0782217
# 1  Barão Geraldo  13084175  -22.8231516  -47.0816365
# 2  Barão Geraldo  13084030  -22.8182648  -47.0934144
# 3  Barão Geraldo  13084020  -22.8206049  -47.0882139
# 4  Barão Geraldo  13084015   -22.818458   -47.090253

# %%
address = 'Barão Geraldo, Campinas'
geolocator = Nominatim(user_agent="bg_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude


#First Toronto map with all neighborhoods

##Create map with folium library and the latitude and longitude variables
map_bg = folium.Map(location=[latitude, longitude], zoom_start=13)

# add markers to map
for lat, lng, bairro in zip(df_barao['latitude'], 
                    df_barao['longitude'],
                    df_barao['bairro']):
    
    #Maker display info
    label = '{}'.format(bairro)
    label = folium.Popup(label, parse_html=True)
    
    #Markers appearance
    folium.CircleMarker(
        [lat, lng],
        radius = 5,
        popup = label,
        color = '#FF0000',
        fill = True,
        fill_color = 'white',
        fill_opacity = 0.7,
        parse_html = False).add_to(map_bg)  
    
map_bg
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Define a function to read a series of names and coordinates and
#lists the first 100 venues located inside a radius of 500m from the neighborhood center. 

def getNearbyVenues(names, latitudes, longitudes, cep, radius=1000, LIMIT = 100):
    
    venues_list=[]
    for name, lat, lng, c in zip(names, latitudes, longitudes, cep):
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
    
        
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name,
            c,
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood',
                             'cep',
                             'Neighborhood Latitude', 
                             'Neighborhood Longitude', 
                             'Venue', 
                             'Venue Latitude', 
                             'Venue Longitude', 
                             'Venue Category']
    
    print('DONE!')
    return(nearby_venues)

# %%
#Execute previous function and get a dataframe with all the venues from Toronto neighborhoods
barao_venues = getNearbyVenues(names = df_barao['bairro'],
                                   cep = df_barao['cep'],
                                   latitudes = df_barao['latitude'],
                                   longitudes = df_barao['longitude']
                                  )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-9b41eeefa149> in <module>
#       1 #Execute previous function and get a dataframe with all the venues from Toronto neighborhoods
# ----> 2 barao_venues = getNearbyVenues(names = df_barao['bairro'],
#       3                                    cep = df_barao['cep'],
#       4                                    latitudes = df_barao['latitude'],
#       5                                    longitudes = df_barao['longitude']
#
# NameError: name 'df_barao' is not defined

# %%
barao_venues.head()
# Out:
#     Neighborhood       cep Neighborhood Latitude Neighborhood Longitude  \
# 0  Barão Geraldo  13084070           -22.8283775            -47.0782217
# 1  Barão Geraldo  13084070           -22.8283775            -47.0782217
# 2  Barão Geraldo  13084070           -22.8283775            -47.0782217
# 3  Barão Geraldo  13084070           -22.8283775            -47.0782217
# 4  Barão Geraldo  13084070           -22.8283775            -47.0782217
#
#                              Venue  Venue Latitude  Venue Longitude  \
# 0                Cervejaria Tabuas      -22.828975       -47.078557
# 1                  Empório do Nono      -22.828482       -47.079088
# 2                  Hot Dog Central      -22.828071       -47.079421
# 3                           Lado B      -22.827392       -47.079115
# 4  Estação Barão Bar e Restaurante      -22.828451       -47.079517
#
#          Venue Category
# 0               Brewery
# 1  Brazilian Restaurant
# 2         Hot Dog Joint
# ...

# %%
h = barao_venues.drop_duplicates(subset ="Venue", 
                     keep = 'first', inplace = False)

# %%
h
# Out:
#                                       Neighborhood       cep  \
# 0                                    Barão Geraldo  13084070
# 1                                    Barão Geraldo  13084070
# 2                                    Barão Geraldo  13084070
# 3                                    Barão Geraldo  13084070
# 4                                    Barão Geraldo  13084070
# ...                                            ...       ...
# 7685  Residencial Estância Eudóxia (Barão Geraldo)  13085554
# 7686  Residencial Estância Eudóxia (Barão Geraldo)  13085554
# 7687  Residencial Estância Eudóxia (Barão Geraldo)  13085554
# 7688  Residencial Estância Eudóxia (Barão Geraldo)  13085554
# 7689  Residencial Estância Eudóxia (Barão Geraldo)  13085554
#
#      Neighborhood Latitude Neighborhood Longitude  \
# 0              -22.8283775            -47.0782217
# 1              -22.8283775            -47.0782217
# 2              -22.8283775            -47.0782217
# ...

# %%
x= h['Venue Category'].value_counts().reset_index()
my_colors = [(x/10.0, x/20.0, 0.75) for x in range(len(df))]
x.plot.barh(x = 'index', y = 'Venue Category', figsize = (10, 20))

# %%
h[h['Venue Category'] == 'Burger Joint']
# Out:
#                                       Neighborhood       cep  \
# 34                                   Barão Geraldo  13084070
# 46                                   Barão Geraldo  13084070
# 52                                   Barão Geraldo  13084070
# 89                                   Barão Geraldo  13084070
# 583                                  Barão Geraldo  13084165
# 3022                                 Barão Geraldo  13084140
# 3025                                 Barão Geraldo  13084140
# 5365       Jardim Santa Genebra II (Barão Geraldo)  13084765
# 7688  Residencial Estância Eudóxia (Barão Geraldo)  13085554
#
#      Neighborhood Latitude Neighborhood Longitude  \
# 34             -22.8283775            -47.0782217
# 46             -22.8283775            -47.0782217
# 52             -22.8283775            -47.0782217
# 89             -22.8283775            -47.0782217
# 583            -22.8265647            -47.0848405
# ...

# %%
barao_onehot = pd.get_dummies(h[['Venue Category']], prefix="", prefix_sep="")
barao_onehot['Neighborhood'] = h['Neighborhood'] 
barao_onehot['cep'] = h['cep'] 


#reorder columns with the neighborhood as the first one
col_list = list(barao_onehot) #Get list of columns headers
col_list.insert(1, col_list.pop(col_list.index('Neighborhood'))) #Remove 'Neighborhood' column and reinsert it at 0 
col_list.insert(0, col_list.pop(col_list.index('cep'))) #Remove 'Neighborhood' column and reinsert it at 0 

barao_onehot = barao_onehot.loc[:, col_list] #Reorder dataframe
barao_grouped = barao_onehot.groupby('cep').mean().reset_index()

barao_grouped.head(10)
#cols_rest = toronto_onehot.columns.str.contains('Restaurant|Neighborhood')
#toronto_rest = toronto_onehot.loc[:,cols_rest]
#toronto_rest.head()
# Out:
#         cep  Acai House  American Restaurant  Arts & Crafts Store  \
# 0  13082754    0.000000                  0.0             0.000000
# 1  13084015    0.000000                  0.0             0.000000
# 2  13084020    0.000000                  0.0             0.000000
# 3  13084030    0.000000                  0.0             0.000000
# 4  13084045    0.000000                  0.0             0.000000
# 5  13084070    0.010526                  0.0             0.010526
# 6  13084135    0.000000                  0.0             0.000000
# 7  13084140    0.000000                  0.0             0.000000
# 8  13084165    0.000000                  0.0             0.000000
# 9  13084175    0.000000                  0.0             0.000000
#
#    Athletics & Sports  BBQ Joint    Bakery       Bar  Bed & Breakfast  \
# 0            0.000000   0.000000  0.166667  0.000000              0.0
# 1            0.000000   0.000000  0.000000  0.000000              0.0
# ...

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending = False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['cep']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['cep'] = barao_grouped['cep']

for ind in np.arange(barao_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(barao_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#         cep    1st Most Common Venue          2nd Most Common Venue  \
# 0  13082754                     Park           Brazilian Restaurant
# 1  13084015                Gastropub                    Music Venue
# 2  13084020                    Motel  Vegetarian / Vegan Restaurant
# 3  13084030                      Bar                   Noodle House
# 4  13084045  Fruit & Vegetable Store                         Bakery
#
#   3rd Most Common Venue          4th Most Common Venue  \
# 0                   Gym                         Bakery
# 1              Dive Bar  Vegetarian / Vegan Restaurant
# 2          Dessert Shop                    Coffee Shop
# 3           Beer Garden                Paintball Field
# 4                   Bar                   Dance Studio
#
#            5th Most Common Venue 6th Most Common Venue  \
# 0           Gym / Fitness Center                School
# 1                   Dessert Shop           Coffee Shop
# ...

# %%
# set number of clusters
kclusters = 4

barao_grouped_clustering = barao_grouped.drop('cep', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(barao_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-27f7f55908d7> in <module>
#       2 kclusters = 4
#       3
# ----> 4 barao_grouped_clustering = barao_grouped.drop('cep', 1)
#       5
#       6 # run k-means clustering
#
# NameError: name 'barao_grouped' is not defined

# %%
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

barao_merged = df_barao

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
barao_merged = barao_merged.join(neighborhoods_venues_sorted.set_index('cep'), on='cep')
barao_merged.head() # check the last columns!
# Out:
#           bairro       cep     latitude    longitude  Cluster Labels  \
# 0  Barão Geraldo  13084070  -22.8283775  -47.0782217             8.0
# 1  Barão Geraldo  13084175  -22.8231516  -47.0816365             8.0
# 2  Barão Geraldo  13084030  -22.8182648  -47.0934144             8.0
# 3  Barão Geraldo  13084020  -22.8206049  -47.0882139             7.0
# 4  Barão Geraldo  13084015   -22.818458   -47.090253             1.0
#
#   1st Most Common Venue          2nd Most Common Venue 3rd Most Common Venue  \
# 0  Brazilian Restaurant                            Bar                  Café
# 1                   Bar           Brazilian Restaurant             Pet Store
# 2                   Bar                   Noodle House           Beer Garden
# 3                 Motel  Vegetarian / Vegan Restaurant          Dessert Shop
# 4             Gastropub                    Music Venue              Dive Bar
#
#            4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# ...

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(barao_merged['latitude'],
                                  barao_merged['longitude'],
                                  barao_merged['bairro'],
                                  barao_merged['Cluster Labels']):
    
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[int(cluster)-1],
        fill=True,
        fill_color=rainbow[int(cluster)-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-701-d9c8a322c1ea> in <module>
#      20         radius=5,
#      21         popup=label,
# ---> 22         color=rainbow[int(cluster)-1],
#      23         fill=True,
#      24         fill_color=rainbow[int(cluster)-1],
#
# ValueError: cannot convert float NaN to integer

# %%
barao_merged['Cluster Labels']
# Out:
# 0      8.0
# 1      8.0
# 2      8.0
# 3      7.0
# 4      1.0
#       ...
# 137    NaN
# 138    NaN
# 139    NaN
# 140    NaN
# 141    NaN
# Name: Cluster Labels, Length: 142, dtype: float64
