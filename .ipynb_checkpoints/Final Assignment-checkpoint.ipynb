# %% [markdown]
# <h2>Imports</h2>

# %%
import pandas as pd
import numpy as np
import time
from sklearn.cluster import KMeans

import requests
import json
from pandas.io.json import json_normalize
import matplotlib.cm as cm
import matplotlib.colors as colors
from collections import OrderedDict
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap, LinearSegmentedColormap

from geopy.geocoders import Nominatim
import folium

# %% [markdown]
# <h2>Credentials</h2>

# %%
#Foursquare
CLIENT_ID = '4TA3CJZNAX3YAOMWZ2ASBNZGULEUZI5E5OABCFPWXRV1UATU' #Foursquare ID
CLIENT_SECRET = 'TJGOQELC1CGZQSVX0QIQNHW3XCOXQJPN1OBSJDIYGLN1KRZX' #Foursquare Secret
VERSION = '20180605' #Foursquare API version

#CEP Aberto
CA_Token = '063caa6671dd4c935642b093e58fc6fd'

# %% [markdown]
# <h2>Functions</h2>

# %% [markdown]
# <h3>Scan CEPs and get coordinates</h3>

# %%
def get_cep_coordinates (cep_dataframe):

    df_b = pd.DataFrame(columns = ['bairro', 'cep', 'latitude', 'longitude'])

    for d in cep_dataframe['CEP']:
        url = "https://www.cepaberto.com/api/v3/cep?cep={}".format(d)
        headers = {'Authorization': 'Token token=063caa6671dd4c935642b093e58fc6fd'}
        response = requests.get(url, headers = headers)

        if response.status_code != 200:
        
            print('REQUEST: FORBIDDEN!:',response.status_code)

            while response.status_code != 200:
                time.sleep(1)
                response = requests.get(url, headers = headers)
        
            print('SOLVED: 400 -> 200')
        
        elif response.status_code == 200:
            print('REQUEST: OK')
            
        j = response.json()
        
        df_b = df_b.append({'bairro' : j['bairro'],
                                    'cep' : j['cep'],
                                    'latitude' : j['latitude'],
                                    'longitude' : j['longitude']},
                                   ignore_index=True)
        
        print('DONE!')
        
    return df_b

# %%
#Define a function to read a series of names and coordinates and
#lists the first 100 venues located inside a radius of 500m from the neighborhood center. 

def getNearbyVenues(names, cep, latitudes, longitudes, radius=1000, LIMIT = 100):
    
    venues_list=[]
    for name, lat, lng, c in zip(names, latitudes, longitudes, cep):
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
    
        
        # make the GET request
        print(url)
        results = requests.get(url).json()['response']['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name,
            c,
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['bairro',
                             'cep',
                             'bairro latitude', 
                             'bairro longitude', 
                             'venue', 
                             'venue latitude', 
                             'venue longitude', 
                             'venue category']
    
    print('DONE!')
    return(nearby_venues)

# %% [markdown]
# <h3>Most Common Venues</h3>

# %%
def return_most_common_venues(row, num_top_venues):
    
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending = False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %% [markdown]
# <h2>Get Addresses</h2>

# %%
raw = []
df_cep = pd.DataFrame(columns = ['LOGRADOURO', 'BAIRRO', 'CIDADE/ESTADO', 'BAIRRO.1', 'CEP'])

for i in range(6): 
    raw.append(
        pd.read_html('https://cep.guiamais.com.br/busca/barao+geraldo-campinas-sp?page={}'.format(i+1), 
                         encoding = 'utf-8'))

for d in raw:
    df_cep = df_cep.append(d[0],
                           ignore_index = True)

df_cep = df_cep.astype(str)
df_cep.sort_values(by = ['BAIRRO'],
                   inplace = True)
df_cep.drop(columns = ['LOGRADOURO', 'BAIRRO.1'], 
            inplace = True)
df_cep['CEP'] = df_cep['CEP'].str.replace(r'-', '')

# %%
df_barao = get_cep_coordinates(df_cep)
df_barao.head()
# Out:
# REQUEST: OK
# DONE!
# REQUEST: OK
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: OK
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: OK
# DONE!
# REQUEST: OK
# DONE!
# REQUEST: OK
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: OK
# DONE!
# REQUEST: OK
# DONE!
# REQUEST: OK
# DONE!
# REQUEST: OK
# DONE!
# REQUEST: OK
# DONE!
# REQUEST: OK
# DONE!
# REQUEST: OK
# DONE!
# REQUEST: OK
# DONE!
# REQUEST: OK
# DONE!
# REQUEST: OK
# DONE!
# REQUEST: OK
# DONE!
# REQUEST: OK
# DONE!
# REQUEST: OK
# DONE!
# REQUEST: OK
# DONE!
# REQUEST: OK
# DONE!
# REQUEST: OK
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: OK
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: OK
# DONE!
# REQUEST: OK
# DONE!
# REQUEST: OK
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: OK
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: OK
# DONE!
# REQUEST: OK
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: OK
# DONE!
# REQUEST: OK
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: OK
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: OK
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: OK
# DONE!
# REQUEST: OK
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: OK
# DONE!
# REQUEST: OK
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: OK
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: OK
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: OK
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: OK
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
# REQUEST: FORBIDDEN!: 403
# SOLVED: 400 -> 200
# DONE!
#           bairro       cep     latitude    longitude
# 0  Barão Geraldo  13084070  -22.8283775  -47.0782217
# 1  Barão Geraldo  13084175  -22.8231516  -47.0816365
# 2  Barão Geraldo  13084030  -22.8182648  -47.0934144
# 3  Barão Geraldo  13084020  -22.8206049  -47.0882139
# 4  Barão Geraldo  13084015   -22.818458   -47.090253

# %%
df_barao.tail(20)
# Out:
#                                            bairro       cep     latitude  \
# 122  Residencial Estância Eudóxia (Barão Geraldo)  13085561  -22.7982815
# 123  Residencial Estância Eudóxia (Barão Geraldo)  13085552  -22.8226801
# 124    Residencial Vitória Ropole (Barão Geraldo)  13082835  -22.8226801
# 125    Residencial Vitória Ropole (Barão Geraldo)  13082827  -22.8226801
# 126    Residencial Vitória Ropole (Barão Geraldo)  13082844  -22.8226801
# 127    Residencial Vitória Ropole (Barão Geraldo)  13082834  -22.8226801
# 128    Residencial Vitória Ropole (Barão Geraldo)  13082842  -22.8226801
# 129    Residencial Vitória Ropole (Barão Geraldo)  13082833  -22.8226801
# 130    Residencial Vitória Ropole (Barão Geraldo)  13082829  -22.8226801
# 131    Residencial Vitória Ropole (Barão Geraldo)  13082836  -22.8226801
# 132    Residencial Vitória Ropole (Barão Geraldo)  13082839  -22.8226801
# 133    Residencial Vitória Ropole (Barão Geraldo)  13082826  -22.8226801
# 134    Residencial Vitória Ropole (Barão Geraldo)  13082832  -22.8226801
# 135    Residencial Vitória Ropole (Barão Geraldo)  13082831  -22.8226801
# 136    Residencial Vitória Ropole (Barão Geraldo)  13082838  -22.8226801
# 137    Residencial Vitória Ropole (Barão Geraldo)  13082828  -22.8226801
# 138    Residencial Vitória Ropole (Barão Geraldo)  13082841  -22.8226801
# 139    Residencial Vitória Ropole (Barão Geraldo)  13082830  -22.8226801
# 140    Residencial Vitória Ropole (Barão Geraldo)  13082843  -22.8226801
# 141    Residencial Vitória Ropole (Barão Geraldo)  13082837  -22.8226801
#
#        longitude
# 122  -47.0706492
# 123  -47.0850446
# 124  -47.0850446
# 125  -47.0850446
# 126  -47.0850446
# 127  -47.0850446
# 128  -47.0850446
# 129  -47.0850446
# 130  -47.0850446
# 131  -47.0850446
# 132  -47.0850446
# 133  -47.0850446
# 134  -47.0850446
# 135  -47.0850446
# 136  -47.0850446
# 137  -47.0850446
# 138  -47.0850446
# 139  -47.0850446
# 140  -47.0850446
# 141  -47.0850446

# %% [markdown]
# <h3>See Barão Geraldo Map with each CEP</h3>

# %%
address = 'Barão Geraldo, Campinas'
geolocator = Nominatim(user_agent="bg_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

#First Barao map with all neighborhoods




b = df_barao['bairro'].unique()
yg = cm.get_cmap('rainbow', len(b))
c = []
for i in range(len(b)): c.append(colors.to_hex(yg(i)))

my_colors = dict(zip(b, c))

##Create map with folium library and the latitude and longitude variables
map_bg = folium.Map(location=[latitude - 0.02, longitude], zoom_start=14)

# add markers to map
for lat, lng, bairro in zip(df_barao['latitude'], 
                    df_barao['longitude'],
                    df_barao['bairro']):
    
    #Maker display info
    label = '{}'.format(bairro)
    label = folium.Popup(label, parse_html=True)
    
    #Markers appearance
    folium.CircleMarker(
        [lat, lng],
        radius = 5,
        popup = label,
        color = my_colors[bairro],
        fill = True,
        fill_color = my_colors[bairro],
        fill_opacity = 0.7,
        parse_html = False).add_to(map_bg)  
    
map_bg
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <h2>Get Venues</h2>

# %%
#Execute previous function and get a dataframe with all the venues from Toronto neighborhoods
barao_venues = getNearbyVenues(names = df_barao['bairro'],
                                   cep = df_barao['cep'],
                                   latitudes = df_barao['latitude'],
                                   longitudes = df_barao['longitude']
                                  )
barao_venues.head()
# Out:
# https://api.foursquare.com/v2/venues/explore?&client_id=4TA3CJZNAX3YAOMWZ2ASBNZGULEUZI5E5OABCFPWXRV1UATU&client_secret=TJGOQELC1CGZQSVX0QIQNHW3XCOXQJPN1OBSJDIYGLN1KRZX&v=20180605&ll=-22.8283775,-47.0782217&radius=1000&limit=100
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-376-31185629b78b> in <module>
#       3                                    cep = df_barao['cep'],
#       4                                    latitudes = df_barao['latitude'],
# ----> 5                                    longitudes = df_barao['longitude']
#       6                                   )
#       7 barao_venues.head()
#
# <ipython-input-375-5675bf0b1e99> in getNearbyVenues(names, cep, latitudes, longitudes, radius, LIMIT)
#      20         # make the GET request
#      21         print(url)
# ---> 22         results = requests.get(url).json()['response']['groups'][0]['items']
#      23
#      24         # return only relevant information for each nearby venue
#
# KeyError: 'groups'

# %%
barao_venues.drop_duplicates(subset ="venue", 
                             keep = 'first', inplace = True)

barao_onehot = pd.get_dummies(barao_venues[['venue category']], prefix="", prefix_sep="")
#barao_onehot['bairro'] = barao_venues['bairro'] 
barao_onehot['cep'] = barao_venues['cep'] 


#reorder columns with the neighborhood as the first one
col_list = list(barao_onehot) #Get list of columns headers
#col_list.insert(1, col_list.pop(col_list.index('bairro')))
col_list.insert(0, col_list.pop(col_list.index('cep'))) 

barao_onehot = barao_onehot.loc[:, col_list] #Reorder dataframe
barao_grouped = barao_onehot.groupby('cep').mean().reset_index()

# %%
num_top_venues = 3

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['cep']

for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['cep'] = barao_grouped['cep']

for ind in np.arange(barao_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(barao_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.shape
# Out:
# (24, 4)

# %% [markdown]
# <h2>Barao Geraldo Venues</h2>

# %%
b = df_barao['venue category'].unique()
yg = cm.get_cmap('rainbow', len(b))
c = []
for i in range(len(b)): c.append(colors.to_hex(yg(i)))

barao_venues['venue category'].nunique()
# Out:
# 88

# %%
address = 'Barão Geraldo, Campinas'
geolocator = Nominatim(user_agent="bg_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

b = barao_venues['venue category'].unique()
yg = cm.get_cmap('rainbow', len(b))
c = []
for i in range(len(b)): c.append(colors.to_hex(yg(i)))
my_colors = dict(zip(b, c))


#First Barao map with all neighborhoods

##Create map with folium library and the latitude and longitude variables
map_bg = folium.Map(location=[latitude - 0.02, longitude], zoom_start=14)

# add markers to map
for lat, lng, category in zip(barao_venues['venue latitude'], 
                    barao_venues['venue longitude'],
                    barao_venues['venue category']):
    
    #Maker display info
    label = '{}'.format(category)
    label = folium.Popup(label, parse_html=True)
    
    #Markers appearance
    folium.CircleMarker(
        [lat, lng],
        radius = 5,
        popup = label,
        color = my_colors[category],
        fill = True,
        fill_color = my_colors[category],
        fill_opacity = 0.7,
        parse_html = False).add_to(map_bg)  
    
map_bg
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
bar_temp = barao_venues['venue category'].value_counts().reset_index()

bar_graph = bar_temp.loc[bar_temp['venue category'] > 1]
bar_graph = bar_graph.rename(columns = {'index' : 'Venue Category', 'venue category' : 'Total'})


ax1 = bar_graph.plot.bar(x = 'Venue Category', 
                   y = 'Total', 
                   figsize = (15, 5))

ax1.set_title('Barão Geraldo Venues by Category', fontsize = 20)
ax1.set_xlabel('Category', fontsize = 15)
ax1.set_ylabel('Total', fontsize = 15)
# Out:
# Text(0, 0.5, 'Total')

# %% [markdown]
# <h3>Most Common Venues and Clustering</h3>

# %%
num_top_venues = 5

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['cep']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['cep'] = barao_grouped['cep']

for ind in np.arange(barao_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(barao_grouped.iloc[ind, :], num_top_venues)


neighborhoods_venues_sorted.shape
# Out:
# (24, 6)

# %%
# set number of clusters
kclusters = 10

barao_grouped_clustering = barao_grouped.drop('cep', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=4).fit(barao_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:num_top_venues] 

# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

barao_merged = df_barao

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
barao_merged = barao_merged.join(neighborhoods_venues_sorted.set_index('cep'), on='cep')

# %%
barao_merged.dropna(inplace = True)
barao_merged['Cluster Labels'] = barao_merged['Cluster Labels'].astype(int)
barao_merged
# Out:
#                                            bairro       cep        latitude  \
# 0                                   Barão Geraldo  13084070     -22.8283775
# 1                                   Barão Geraldo  13084175     -22.8231516
# 2                                   Barão Geraldo  13084030     -22.8182648
# 3                                   Barão Geraldo  13084020     -22.8206049
# 4                                   Barão Geraldo  13084015      -22.818458
# 8                                   Barão Geraldo  13084165     -22.8265647
# 11                                  Barão Geraldo  13084215     -22.8272253
# 12                                  Barão Geraldo  13084200     -22.8212066
# 18                                  Barão Geraldo  13084180     -22.8212364
# 19                                  Barão Geraldo  13085850     -22.7835333
# 21                                  Barão Geraldo  13084135     -22.8210688
# 22                                  Barão Geraldo  13084045     -22.8184204
# 37                                  Barão Geraldo  13084125     -22.8196929
# 40                                  Barão Geraldo  13084140     -22.8279428
# 53                        Bosque de Barão Geraldo  13082754     -22.8273433
# 66                      Jardim Novo Barão Geraldo  13084727      -22.821452
# 68                      Jardim Novo Barão Geraldo  13084726     -22.8218153
# 69                      Jardim Novo Barão Geraldo  13084723     -22.8234998
# 73        Jardim Santa Genebra II (Barão Geraldo)  13084766  -22.8389499931
# 80        Jardim Santa Genebra II (Barão Geraldo)  13084765     -22.8351406
# 84        Jardim Santa Genebra II (Barão Geraldo)  13084758     -22.8347021
# 86        Jardim Santa Genebra II (Barão Geraldo)  13084789     -22.8336628
# 104       Jardim Santa Genebra II (Barão Geraldo)  13084775      -22.832167
# 113  Residencial Estância Eudóxia (Barão Geraldo)  13085554     -22.7982815
#
#           longitude  Cluster Labels    1st Most Common Venue  \
# 0       -47.0782217               1     Brazilian Restaurant
# 1       -47.0816365               1                Pet Store
# 2       -47.0934144               1                      Bar
# 3       -47.0882139               7                    Motel
# 4        -47.090253               1                Gastropub
# 8       -47.0848405               1         Lottery Retailer
# 11      -47.0819026               5               Smoke Shop
# 12      -47.0834485               1               Food Truck
# 18       -47.081627               8                      Bar
# 19      -47.0490539               1           Gymnastics Gym
# 21      -47.0815588               2     Brazilian Restaurant
# 22      -47.0888251               1  Fruit & Vegetable Store
# 37      -47.0824082               4             Optical Shop
# 40      -47.0767646               2     Brazilian Restaurant
# 53      -47.1027559               1                      Gym
# 66      -47.0763068               1        College Cafeteria
# 68      -47.0779786               0              Music Venue
# 69      -47.0765396               6                BBQ Joint
# 73   -46.9882101219               9                 Platform
# 80      -47.0783589               1     Brazilian Restaurant
# 84      -47.0781419               2     Brazilian Restaurant
# 86      -47.0757052               3        Convenience Store
# 104     -47.0745643               1              Gas Station
# 113     -47.0706492               1      American Restaurant
#
#              2nd Most Common Venue          3rd Most Common Venue  \
# 0                              Bar                    Pizza Place
# 1             Brazilian Restaurant                            Bar
# 2                    Hot Dog Joint                            Gym
# 3    Vegetarian / Vegan Restaurant                  Grocery Store
# 4                      Music Venue                       Dive Bar
# 8                         Bus Stop                  Hot Dog Joint
# 11   Vegetarian / Vegan Restaurant                      Dive Shop
# 12                  Ice Cream Shop  Vegetarian / Vegan Restaurant
# 18   Vegetarian / Vegan Restaurant                           Farm
# 19                     Music Venue                         Bakery
# 21   Vegetarian / Vegan Restaurant                 Clothing Store
# 22                             Bar  Vegetarian / Vegan Restaurant
# 37   Vegetarian / Vegan Restaurant                  Grocery Store
# 40                    Burger Joint                 Ice Cream Shop
# 53                          Bakery           Brazilian Restaurant
# 66                       Juice Bar             Athletics & Sports
# 68   Vegetarian / Vegan Restaurant                  Grocery Store
# 69   Vegetarian / Vegan Restaurant                           Farm
# 73                            Farm  Vegetarian / Vegan Restaurant
# 80                     Snack Place                            Bar
# 84                          Garden  Vegetarian / Vegan Restaurant
# 86   Vegetarian / Vegan Restaurant                  Travel Agency
# 104                      Pet Store                       Pharmacy
# 113        Fruit & Vegetable Store                         Bakery
#
#              4th Most Common Venue          5th Most Common Venue
# 0                             Café                        Brewery
# 1                       Skate Park                  Hot Dog Joint
# 2                       Restaurant                     Food Truck
# 3                      Coffee Shop              College Cafeteria
# 4                    Grocery Store                    Coffee Shop
# 8                      Pizza Place                   Burger Joint
# 11                     Coffee Shop              College Cafeteria
# 12                       Dive Shop                    Coffee Shop
# 18               College Cafeteria        Comfort Food Restaurant
# 19                      Restaurant  Vegetarian / Vegan Restaurant
# 21               College Cafeteria        Comfort Food Restaurant
# 22                            Farm              College Cafeteria
# 37                     Coffee Shop              College Cafeteria
# 40   Vegetarian / Vegan Restaurant              College Cafeteria
# 53                          School                           Park
# 66           Performing Arts Venue                           Café
# 68                     Coffee Shop              College Cafeteria
# 69               College Cafeteria        Comfort Food Restaurant
# 73                        Dive Bar                    Coffee Shop
# 80                       Bookstore              Martial Arts Dojo
# 84               College Cafeteria        Comfort Food Restaurant
# 86                     Coffee Shop              College Cafeteria
# 104                    Pizza Place             Chinese Restaurant
# 113             Miscellaneous Shop                   Burger Joint

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(barao_merged['latitude'],
                                  barao_merged['longitude'],
                                  barao_merged['bairro'],
                                  barao_merged['Cluster Labels']):
    
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
barao_merged.loc[barao_merged['Cluster Labels'] == 0, barao_merged.columns[[1] + list(range(5, barao_merged.shape[1]))]]
# Out:
#          cep 1st Most Common Venue          2nd Most Common Venue  \
# 68  13084726           Music Venue  Vegetarian / Vegan Restaurant
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue
# 68         Grocery Store           Coffee Shop     College Cafeteria

# %%
barao_merged.loc[barao_merged['Cluster Labels'] == 1, barao_merged.columns[[1] + list(range(5, barao_merged.shape[1]))]]
# Out:
#           cep    1st Most Common Venue    2nd Most Common Venue  \
# 0    13084070     Brazilian Restaurant                      Bar
# 1    13084175                Pet Store     Brazilian Restaurant
# 2    13084030                      Bar            Hot Dog Joint
# 4    13084015                Gastropub              Music Venue
# 8    13084165         Lottery Retailer                 Bus Stop
# 12   13084200               Food Truck           Ice Cream Shop
# 19   13085850           Gymnastics Gym              Music Venue
# 22   13084045  Fruit & Vegetable Store                      Bar
# 53   13082754                      Gym                   Bakery
# 66   13084727        College Cafeteria                Juice Bar
# 80   13084765     Brazilian Restaurant              Snack Place
# 104  13084775              Gas Station                Pet Store
# 113  13085554      American Restaurant  Fruit & Vegetable Store
#
#              3rd Most Common Venue  4th Most Common Venue  \
# 0                      Pizza Place                   Café
# 1                              Bar             Skate Park
# 2                              Gym             Restaurant
# 4                         Dive Bar          Grocery Store
# 8                    Hot Dog Joint            Pizza Place
# 12   Vegetarian / Vegan Restaurant              Dive Shop
# 19                          Bakery             Restaurant
# 22   Vegetarian / Vegan Restaurant                   Farm
# 53            Brazilian Restaurant                 School
# 66              Athletics & Sports  Performing Arts Venue
# 80                             Bar              Bookstore
# 104                       Pharmacy            Pizza Place
# 113                         Bakery     Miscellaneous Shop
#
#              5th Most Common Venue
# 0                          Brewery
# 1                    Hot Dog Joint
# 2                       Food Truck
# 4                      Coffee Shop
# 8                     Burger Joint
# 12                     Coffee Shop
# 19   Vegetarian / Vegan Restaurant
# 22               College Cafeteria
# 53                            Park
# 66                            Café
# 80               Martial Arts Dojo
# 104             Chinese Restaurant
# 113                   Burger Joint

# %%
barao_merged.loc[barao_merged['Cluster Labels'] == 2, barao_merged.columns[[1] + list(range(5, barao_merged.shape[1]))]]
# Out:
#          cep 1st Most Common Venue          2nd Most Common Venue  \
# 21  13084135  Brazilian Restaurant  Vegetarian / Vegan Restaurant
# 40  13084140  Brazilian Restaurant                   Burger Joint
# 84  13084758  Brazilian Restaurant                         Garden
#
#             3rd Most Common Venue          4th Most Common Venue  \
# 21                 Clothing Store              College Cafeteria
# 40                 Ice Cream Shop  Vegetarian / Vegan Restaurant
# 84  Vegetarian / Vegan Restaurant              College Cafeteria
#
#       5th Most Common Venue
# 21  Comfort Food Restaurant
# 40        College Cafeteria
# 84  Comfort Food Restaurant

# %%
barao_merged.loc[barao_merged['Cluster Labels'] == 3, barao_merged.columns[[1] + list(range(5, barao_merged.shape[1]))]]
# Out:
#          cep 1st Most Common Venue          2nd Most Common Venue  \
# 86  13084789     Convenience Store  Vegetarian / Vegan Restaurant
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue
# 86         Travel Agency           Coffee Shop     College Cafeteria

# %%
barao_merged.loc[barao_merged['Cluster Labels'] == 4, barao_merged.columns[[1] + list(range(5, barao_merged.shape[1]))]]
# Out:
#          cep 1st Most Common Venue          2nd Most Common Venue  \
# 37  13084125          Optical Shop  Vegetarian / Vegan Restaurant
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue
# 37         Grocery Store           Coffee Shop     College Cafeteria

# %%
barao_merged.loc[barao_merged['Cluster Labels'] == 5, barao_merged.columns[[1] + list(range(5, barao_merged.shape[1]))]]
# Out:
#          cep 1st Most Common Venue          2nd Most Common Venue  \
# 11  13084215            Smoke Shop  Vegetarian / Vegan Restaurant
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue
# 11             Dive Shop           Coffee Shop     College Cafeteria

# %%
barao_merged.loc[barao_merged['Cluster Labels'] == 6, barao_merged.columns[[1] + list(range(5, barao_merged.shape[1]))]]
# Out:
#          cep 1st Most Common Venue          2nd Most Common Venue  \
# 69  13084723             BBQ Joint  Vegetarian / Vegan Restaurant
#
#    3rd Most Common Venue 4th Most Common Venue    5th Most Common Venue
# 69                  Farm     College Cafeteria  Comfort Food Restaurant

# %%
barao_merged.loc[barao_merged['Cluster Labels'] == 7, barao_merged.columns[[1] + list(range(5, barao_merged.shape[1]))]]
# Out:
#         cep 1st Most Common Venue          2nd Most Common Venue  \
# 3  13084020                 Motel  Vegetarian / Vegan Restaurant
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue
# 3         Grocery Store           Coffee Shop     College Cafeteria

# %%
barao_merged.loc[barao_merged['Cluster Labels'] == 8, barao_merged.columns[[1] + list(range(5, barao_merged.shape[1]))]]
# Out:
#          cep 1st Most Common Venue          2nd Most Common Venue  \
# 18  13084180                   Bar  Vegetarian / Vegan Restaurant
#
#    3rd Most Common Venue 4th Most Common Venue    5th Most Common Venue
# 18                  Farm     College Cafeteria  Comfort Food Restaurant

# %%
barao_merged.loc[barao_merged['Cluster Labels'] == 9, barao_merged.columns[[1] + list(range(5, barao_merged.shape[1]))]]
# Out:
#          cep 1st Most Common Venue 2nd Most Common Venue  \
# 73  13084766              Platform                  Farm
#
#             3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue
# 73  Vegetarian / Vegan Restaurant              Dive Bar           Coffee Shop
